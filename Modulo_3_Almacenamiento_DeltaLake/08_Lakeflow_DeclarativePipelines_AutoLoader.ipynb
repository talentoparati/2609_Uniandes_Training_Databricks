# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(135deg,#0a2a6e 0%,#0d5c8a 45%,#0d9488 100%);padding:22px 18px 18px 18px;border-radius:12px 12px 0 0;">
#   <div style="display:flex;justify-content:space-between;align-items:flex-start;flex-wrap:wrap;gap:8px;">
#     <div style="flex:1;min-width:0;">
#       <span style="background:rgba(255,255,255,0.18);color:#a8f0e0;font-size:10px;letter-spacing:2px;padding:3px 10px;border-radius:20px;font-weight:600;">DATABRICKS &nbsp;&middot;&nbsp; MODULO 3 &nbsp;&middot;&nbsp; SESION 8</span>
#       <h1 style="color:#ffffff;font-size:21px;margin:10px 0 4px 0;font-weight:700;">Lakeflow Declarative Pipelines y Auto Loader (3/3) + Cierre del Modulo</h1>
#       <p style="color:#b2f0e8;font-size:13px;margin:0;">Semana 3 &middot; E-commerce: abandono de carrito y deteccion de fraude</p>
#     </div>
#     <div style="text-align:right;flex-shrink:0;">
#       <div style="color:#ffffff;font-size:15px;font-weight:800;">Uniandes</div>
#       <div style="color:#7de8d8;font-size:10px;margin-top:2px;">Educacion Continua &middot; Databricks 2026</div>
#     </div>
#   </div>
# </div>
# <div style="box-sizing:border-box;width:100%;background:#0f172a;padding:12px 18px;border-radius:0 0 12px 12px;margin-bottom:6px;">
#   <table style="width:100%;border-collapse:collapse;table-layout:fixed;">
#     <tr>
#       <td style="width:33%;padding:8px 10px 8px 0;border-right:1px solid #1e3a5f;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">OBJETIVO</div>
#         <div style="color:#e2e8f0;font-size:12px;">Ingerir archivos incrementales con Auto Loader y entender el modelo declarativo de Lakeflow Pipelines</div>
#       </td>
#       <td style="width:33%;padding:8px 10px;border-right:1px solid #1e3a5f;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">PREREQUISITO</div>
#         <div style="color:#e2e8f0;font-size:12px;">Sesion 7 completada</div>
#       </td>
#       <td style="width:33%;padding:8px 0 8px 10px;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">EJECUCION</div>
#         <div style="color:#e2e8f0;font-size:12px;">Sesion 8 — clase en vivo</div>
#       </td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0f172a;padding:12px 18px;border-radius:0 0 12px 12px;margin-bottom:6px;">
#   <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:8px;">OBJETIVOS DE LA SESION</div>
#   <div style="display:flex;flex-wrap:wrap;gap:8px;">
#     <div style="flex:1;min-width:200px;background:#1e3a5f;padding:10px 12px;border-radius:8px;color:#93c5fd;font-size:12px;"><strong style="color:#e2e8f0;">Tema 3.7:</strong> Auto Loader: ingesta incremental de archivos con cloudFiles</div>
#     <div style="flex:1;min-width:200px;background:#1e3a5f;padding:10px 12px;border-radius:8px;color:#93c5fd;font-size:12px;"><strong style="color:#e2e8f0;">Tema 3.8:</strong> Lakeflow Declarative Pipelines: el modelo declarativo de principio a fin</div>
#   </div>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Ejecuta <code style="color:#38bdf8;">00_Configuracion</code> y hereda <code style="color:#38bdf8;">CATALOG_NAME</code>, los nombres de schema, la funcion <code style="color:#38bdf8;">tbl()</code> y las demas variables compartidas del curso.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Es la primera celda de codigo obligatoria en <strong style="color:#e2e8f0;">todo</strong> notebook del curso — sin ella no hay forma de nombrar una tabla. Evita repetir (y desincronizar) la configuracion en los 16 notebooks del curso.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">%run</code> ejecuta <code style="color:#38bdf8;">00_Setup/00_Configuracion.py</code> dentro de esta misma sesion de Spark; sus variables Python quedan disponibles aqui como si se hubieran definido en esta celda — a diferencia de un <code style="color:#38bdf8;">import</code>, comparten el mismo <code style="color:#38bdf8;">SparkSession</code>.</td>
#     </tr>
#   </table>
# </div>

# %%
# %run ../00_Setup/00_Configuracion

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Importa las funciones (<code style="color:#38bdf8;">F</code>), tipos y clases de PySpark que usa el resto de este notebook.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Sin estos imports, funciones como <code style="color:#38bdf8;">F.col()</code> o clases como <code style="color:#38bdf8;">Window</code>/<code style="color:#38bdf8;">DecimalType</code> no existen todavia en esta celda — Python fallaria con <code style="color:#38bdf8;">NameError</code> en la primera linea que las use.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;">Imports estandar de PySpark. <code style="color:#38bdf8;">%run</code> comparte variables pero <strong style="color:#e2e8f0;">no</strong> comparte imports entre notebooks — cada notebook importa lo que necesita, aunque todos usen el mismo <code style="color:#38bdf8;">SparkSession</code> heredado en la celda anterior.</td>
#     </tr>
#   </table>
# </div>

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import *

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA 3.7</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">Auto Loader: ingesta incremental de archivos</h2>
# </div>

# %% [markdown]
# Hasta ahora todas las cargas fueron manuales: generamos un DataFrame y lo escribimos. En un sistema real, los archivos **llegan solos** a un almacenamiento (un Volume, un bucket) y alguien tiene que detectarlos e ingerirlos sin reprocesar lo que ya se cargo. Eso es exactamente lo que hace **Auto Loader**.

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Escribe un archivo JSON con 200 eventos sinteticos directamente en el Volume <code style="color:#38bdf8;">landing</code> creado en el Setup.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Simular la llegada de un archivo nuevo desde un sistema externo (un microservicio de checkout, por ejemplo) — sin este archivo no hay nada nuevo que Auto Loader pueda detectar en la celda siguiente.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">dbutils.fs.mkdirs</code>/<code style="color:#38bdf8;">dbutils.fs.put</code> son utilidades de Databricks para manipular archivos en Volumes/DBFS directamente desde Python, sin pasar por Spark.</td>
#     </tr>
#   </table>
# </div>

# %%
import json, random
from datetime import datetime, timezone

LANDING_PATH = f"/Volumes/{CATALOG_NAME}/{SCHEMA_BRONZE}/{VOLUME_LANDING}/eventos_carrito"
dbutils.fs.mkdirs(LANDING_PATH)

# Simula un archivo nuevo llegando desde un sistema externo (p.ej. un microservicio de checkout)
nuevos_eventos = []
for i in range(200):
    nuevos_eventos.append({
        "evento_id": 9_000_000 + i,
        "sesion_id": f"SES-{random.randint(1, NUM_SESIONES):07d}",
        "cliente_id": random.randint(1, NUM_CLIENTES),
        "producto_id": random.randint(1, 600),
        "tipo_evento": random.choice(["view_product", "add_to_cart", "begin_checkout", "purchase"]),
        "cantidad": random.randint(1, 3),
        "precio_unitario": round(random.uniform(20000, 500000), 2),
        "event_timestamp": datetime.now(timezone.utc).isoformat(),
    })

archivo = f"{LANDING_PATH}/eventos_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"
dbutils.fs.put(archivo, "\n".join(json.dumps(r) for r in nuevos_eventos), overwrite=True)
print(f"[OK] Archivo simulado escrito: {archivo}")
print(f"Eventos en el archivo: {len(nuevos_eventos)}")

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Lee el Volume con Auto Loader (<code style="color:#38bdf8;">cloudFiles</code>) y escribe solo los archivos nuevos en <code style="color:#38bdf8;">bronze.eventos_carrito_streaming</code>.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Demostrar el patron real de ingesta incremental: si se re-ejecuta esta misma celda sin agregar un archivo nuevo, no se ingiere nada de nuevo — Auto Loader recuerda, via el checkpoint, que ya proceso ese archivo.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">cloudFiles.format("json")</code> mas <code style="color:#38bdf8;">cloudFiles.schemaLocation</code> (dentro del propio Volume, la practica recomendada) detectan archivos nuevos incrementalmente. <code style="color:#38bdf8;">trigger(availableNow=True)</code> procesa todo lo disponible y se detiene solo — convierte un stream continuo en un batch incremental, ideal para un Job programado.</td>
#     </tr>
#   </table>
# </div>

# %%
# Auto Loader — lee SOLO archivos nuevos desde la ultima ejecucion (checkpoint)
CHECKPOINT_PATH = f"/Volumes/{CATALOG_NAME}/{SCHEMA_BRONZE}/{VOLUME_LANDING}/_checkpoints/eventos_carrito"

df_autoloader = (
    spark.readStream
    .format("cloudFiles")
    .option("cloudFiles.format", "json")
    .option("cloudFiles.schemaLocation", CHECKPOINT_PATH)
    .load(LANDING_PATH)
)

(
    df_autoloader.writeStream
    .format("delta")
    .option("checkpointLocation", CHECKPOINT_PATH)
    .trigger(availableNow=True)          # procesa lo disponible y se detiene — ideal para Jobs programados
    .toTable(tbl(SCHEMA_BRONZE, "eventos_carrito_streaming"))
)

print(f"[OK] {tbl(SCHEMA_BRONZE, 'eventos_carrito_streaming')} — {spark.table(tbl(SCHEMA_BRONZE, 'eventos_carrito_streaming')).count():,} registros ingeridos")
display(spark.table(tbl(SCHEMA_BRONZE, "eventos_carrito_streaming")).limit(5))

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border-left:4px solid #0d9488;padding:14px 16px;border-radius:6px;margin:10px 0;">
#   <span style="color:#0d9488;font-size:11px;font-weight:700;letter-spacing:1px;">PATRON DE PRODUCCION</span><br/>
#   <span style="color:#cbd5e1;font-size:13px;"><code style="color:#38bdf8;">trigger(availableNow=True)</code> convierte un stream — que normalmente corre indefinidamente — en un <strong style="color:#e2e8f0;">batch incremental</strong>: procesa todo lo que llego desde la ultima vez y se detiene solo. Este patron es el que se usa dentro de un Job programado (Modulo 5): cada ejecucion procesa unicamente lo nuevo, sin necesidad de un cluster corriendo 24/7. Funciona igual sobre Compute Serverless de Free Edition.</span>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA 3.8</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">Lakeflow Declarative Pipelines: el modelo declarativo</h2>
# </div>

# %% [markdown]
# **Lakeflow Declarative Pipelines** (antes "Delta Live Tables") llevan el paradigma declarativo — ya visto en el Modulo 2 con DataFrame API vs SQL — un nivel mas arriba: en vez de escribir <em>como</em> orquestar bronze &rarr; silver &rarr; gold (que tabla depende de cual, en que orden, con reintentos), se declara <em>que</em> tabla existe y de donde sale, y el motor de Lakeflow resuelve el grafo de dependencias, la orquestacion y el manejo de errores automaticamente.
#
# Un pipeline declarativo **no se ejecuta como un notebook normal** — se define en un archivo separado y se corre como un recurso de tipo *Pipeline* desde Workflows. Este curso incluye ese archivo junto a este notebook:
#
# &rarr; [`08b_Pipeline_DLT_Definicion.py`](./08b_Pipeline_DLT_Definicion.py)

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border-left:4px solid #f59e0b;padding:14px 16px;border-radius:6px;margin:10px 0;">
#   <span style="color:#f59e0b;font-size:11px;font-weight:700;letter-spacing:1px;">LIMITE DE DATABRICKS FREE EDITION</span><br/>
#   <span style="color:#cbd5e1;font-size:13px;">Disponible en Databricks Free Edition con un limite claro: <strong style="color:#e2e8f0;">1 pipeline activo por tipo</strong>. Este notebook crea el pipeline Bronze &rarr; Silver; el Modulo 5 (Sesion 12) lo <strong>extiende</strong> hasta Gold editando el mismo recurso — no crea un segundo pipeline. Si ya creaste este en tu workspace, en el Modulo 5 solo actualizas su codigo fuente.</span>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Lee e imprime el contenido completo del archivo <code style="color:#38bdf8;">08b_Pipeline_DLT_Definicion.py</code>.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">No se puede "correr" un pipeline declarativo con <code style="color:#38bdf8;">%run</code> como los demas notebooks del curso — por eso vive en un archivo aparte. Aqui solo lo <strong style="color:#e2e8f0;">leemos</strong> para estudiar su sintaxis antes de crearlo como recurso.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">open(...).read()</code> es simple lectura de texto — el archivo esta en la misma carpeta que este notebook dentro del Git folder, por eso la ruta relativa funciona.</td>
#     </tr>
#   </table>
# </div>

# %%
with open("08b_Pipeline_DLT_Definicion.py", "r", encoding="utf-8") as f:
    print(f.read())

# %% [markdown]
# **Como se crearia este pipeline como recurso** (no se ejecuta en este demo — se retoma en el Modulo 5):
# 1. `Workflows > Lakeflow Declarative Pipelines > Create Pipeline`.
# 2. Source code: apuntar a `Modulo_3_Almacenamiento_DeltaLake/08b_Pipeline_DLT_Definicion.py`.
# 3. Destination: el mismo catalog del widget `catalog_name` (por defecto `ecommerce_training`), schema `silver`.
# 4. Pipeline mode: **Triggered** (corre bajo demanda o programado desde un Job) — no *Continuous*, para controlar costo y respetar el limite de 1 pipeline activo por tipo de Free Edition.

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0f172a;border:1px solid #0d9488;padding:18px 16px;border-radius:10px;margin:20px 0;">
#   <div style="color:#0d9488;font-size:13px;font-weight:700;letter-spacing:1px;margin-bottom:16px;">CIERRE DEL MODULO 3</div>
#   <div style="color:#cbd5e1;font-size:13px;line-height:1.7;">
# <strong style="color:#e2e8f0;">Sesion 6:</strong> ACID con UPDATE auditado por Time Travel; MERGE INTO para upserts incrementales sin reescribir la tabla.<br/>
#       <strong style="color:#e2e8f0;">Sesion 7:</strong> diagnostico y solucion del problema de archivos pequenos con OPTIMIZE + ZORDER; Liquid Clustering (CLUSTER BY AUTO) como alternativa moderna; gestion de retencion con VACUUM; SQL Warehouse.<br/>
#       <strong style="color:#e2e8f0;">Sesion 8:</strong> ingesta incremental de archivos con Auto Loader (cloudFiles); introduccion a Lakeflow Declarative Pipelines como capa declarativa sobre toda la arquitectura Medallion.<br/><br/>
#       En el <strong style="color:#e2e8f0;">Modulo 4</strong> nos movemos de almacenamiento a <strong>gobernanza</strong>: permisos, linaje y auditoria sobre todo lo que hemos construido con Unity Catalog.
#   </div>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d9488);height:3px;border-radius:2px;margin:20px 0 8px 0;"></div>
# <div style="box-sizing:border-box;width:100%;display:flex;justify-content:space-between;color:#64748b;font-size:12px;">
#   <span>Modulo 3 &middot; Sesion 8 &middot; Fin del Modulo 3 &nbsp;&middot;&nbsp; Siguiente: <strong>Modulo 4 &middot; Sesion 9 &mdash; Administracion con Unity Catalog</strong></span>
# </div>
