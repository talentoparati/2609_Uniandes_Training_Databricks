# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(135deg,#0a2a6e 0%,#0d5c8a 45%,#0d9488 100%);padding:22px 18px 18px 18px;border-radius:12px 12px 0 0;">
#   <div style="display:flex;justify-content:space-between;align-items:flex-start;flex-wrap:wrap;gap:8px;">
#     <div style="flex:1;min-width:0;">
#       <span style="background:rgba(255,255,255,0.18);color:#a8f0e0;font-size:10px;letter-spacing:2px;padding:3px 10px;border-radius:20px;font-weight:600;">DATABRICKS &nbsp;&middot;&nbsp; MODULO 1 &nbsp;&middot;&nbsp; SESION 1</span>
#       <h1 style="color:#ffffff;font-size:21px;margin:10px 0 4px 0;font-weight:700;">Bienvenida + Arquitectura Lakehouse (1/2)</h1>
#       <p style="color:#b2f0e8;font-size:13px;margin:0;">Semana 1 &middot; E-commerce: abandono de carrito y deteccion de fraude</p>
#     </div>
#     <div style="text-align:right;flex-shrink:0;">
#       <div style="color:#ffffff;font-size:15px;font-weight:800;">Uniandes</div>
#       <div style="color:#7de8d8;font-size:10px;margin-top:2px;">Educacion Continua &middot; Databricks 2026</div>
#     </div>
#   </div>
# </div>
# <div style="box-sizing:border-box;width:100%;background:#0f172a;padding:12px 18px;border-radius:0 0 12px 12px;margin-bottom:6px;">
#   <table style="width:100%;border-collapse:collapse;table-layout:fixed;">
#     <tr>
#       <td style="width:33%;padding:8px 10px 8px 0;border-right:1px solid #1e3a5f;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">OBJETIVO</div>
#         <div style="color:#e2e8f0;font-size:12px;">Entender por que el Lakehouse reemplaza al par Data Warehouse / Data Lake y dar el primer vistazo al workspace</div>
#       </td>
#       <td style="width:33%;padding:8px 10px;border-right:1px solid #1e3a5f;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">PREREQUISITO</div>
#         <div style="color:#e2e8f0;font-size:12px;">Haber ejecutado 00_Setup/01_Generacion_Datos_Sinteticos (una sola vez)</div>
#       </td>
#       <td style="width:33%;padding:8px 0 8px 10px;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">EJECUCION</div>
#         <div style="color:#e2e8f0;font-size:12px;">Sesion 1 — clase en vivo, Databricks Free Edition</div>
#       </td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0f172a;border-left:4px solid #0d9488;padding:14px 16px;border-radius:6px;margin:10px 0;">
#   <div style="color:#0d9488;font-size:10px;letter-spacing:1.5px;font-weight:600;margin-bottom:8px;">MAPA DEL CURSO</div>
#   <table style="color:#cbd5e1;font-size:12px;width:100%;border-collapse:collapse;">
#     <tr style="color:#64748b;font-size:10px;"><td style="padding:3px 10px 3px 0;">MODULO</td><td style="padding:3px 10px;">CONTENIDO</td><td style="padding:3px 10px;">SESIONES</td><td style="padding:3px 0 3px 10px;">TEMAS CLAVE</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;background:#0f2e2b;"><td style="padding:6px 10px 6px 0;color:#0d9488;font-weight:700;">M1</td><td style="padding:6px 10px;color:#e2e8f0;">Fundamentos de Databricks</td><td style="padding:6px 10px;color:#64748b;">Sesiones 1-2</td><td style="padding:6px 0 6px 10px;color:#93c5fd;">Lakehouse, entorno de trabajo, Unity Catalog (intro), Git folders</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:6px 10px 6px 0;color:#0d9488;font-weight:700;">M2</td><td style="padding:6px 10px;color:#e2e8f0;">Procesamiento con Apache Spark</td><td style="padding:6px 10px;color:#64748b;">Sesiones 3-5</td><td style="padding:6px 0 6px 10px;color:#93c5fd;">PySpark DataFrame API, Spark SQL, joins, ventanas, tuning</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:6px 10px 6px 0;color:#0d9488;font-weight:700;">M3</td><td style="padding:6px 10px;color:#e2e8f0;">Almacenamiento</td><td style="padding:6px 10px;color:#64748b;">Sesiones 6-8</td><td style="padding:6px 0 6px 10px;color:#93c5fd;">Delta Lake (ACID, time travel, MERGE, OPTIMIZE, ZORDER), DLT, Auto Loader</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:6px 10px 6px 0;color:#0d9488;font-weight:700;">M4</td><td style="padding:6px 10px;color:#e2e8f0;">Gobernanza</td><td style="padding:6px 10px;color:#64748b;">Sesiones 9-10</td><td style="padding:6px 0 6px 10px;color:#93c5fd;">Unity Catalog: permisos, linaje, auditoria</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:6px 10px 6px 0;color:#0d9488;font-weight:700;">M5</td><td style="padding:6px 10px;color:#e2e8f0;">Ingenieria de Datos</td><td style="padding:6px 10px;color:#64748b;">Sesiones 11-13</td><td style="padding:6px 0 6px 10px;color:#93c5fd;">Workflows, Lakeflow Declarative Pipelines, orquestacion, alertas</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:6px 10px 6px 0;color:#0d9488;font-weight:700;">M6</td><td style="padding:6px 10px;color:#e2e8f0;">Machine Learning</td><td style="padding:6px 10px;color:#64748b;">Sesiones 14-16</td><td style="padding:6px 0 6px 10px;color:#93c5fd;">MLflow, Feature Engineering, Model Registry, Model Serving, proyecto final</td></tr>
#   </table>
# </div>

# %% [markdown]
# ### Bienvenida
#
# Durante 6 modulos y 16 sesiones vamos a construir, de punta a punta, la plataforma de datos de una tienda de e-commerce: desde la ingesta cruda hasta un modelo de Machine Learning en produccion que detecta fraude. Cada sesion es una **secuencia** de la anterior — los notebooks de la Sesion 5 leen tablas que se crearon en la Sesion 3, y asi sucesivamente hasta el proyecto final.
#
# **El caso:** la tienda quiere responder dos preguntas de negocio:
# 1. ¿Por que los usuarios agregan productos al carrito y no completan la compra? (*abandono de carrito*)
# 2. ¿Como detectar una transaccion fraudulenta antes de que se complete? (*deteccion de fraude*)
#
# Todo el dataset (clientes, productos, sesiones web, eventos de carrito, transacciones) ya fue generado por el notebook de Setup. Hoy lo vamos a explorar por primera vez.

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA 1.1</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">Data Warehouse, Data Lake y Lakehouse</h2>
# </div>

# %% [markdown]
# Antes de tocar una sola linea de codigo, es clave entender **por que existe** el Lakehouse.
#
# | Criterio | Data Warehouse | Data Lake | Lakehouse |
# |---|---|---|---|
# | Tipos de dato | Estructurado (tablas) | Cualquiera (json, imagenes, logs) | Cualquiera, con metadata estructurada |
# | Transacciones ACID | Si (nativo) | No | **Si** (Delta Lake) |
# | Costo de almacenamiento | Alto (propietario) | Bajo (object storage) | Bajo (object storage) |
# | Motor de consulta | Propietario, acoplado al storage | Cualquiera (desacoplado) | Cualquiera (desacoplado) |
# | Machine Learning | Dificil (datos ya agregados) | Facil (datos crudos) | Facil (datos crudos + ACID) |
# | Gobierno de datos | Fuerte | Debil ("data swamp") | Fuerte (Unity Catalog) |
#
# **La idea central del Lakehouse:** tomar el almacenamiento barato y abierto del Data Lake (archivos Parquet en object storage) y agregarle encima una capa transaccional — **Delta Lake** — que le da las garantias ACID que antes solo tenia un Data Warehouse. Eso es exactamente lo que vamos a construir con nuestras 5 tablas Bronze.

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Ejecuta <code style="color:#38bdf8;">00_Configuracion</code> y trae <code style="color:#38bdf8;">CATALOG_NAME</code>, los nombres de schema y la funcion <code style="color:#38bdf8;">tbl()</code> a este notebook.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Sin estas variables ninguna celda siguiente puede nombrar una tabla — es el primer paso obligatorio de <strong style="color:#e2e8f0;">todos</strong> los notebooks del curso, siempre la primera celda de codigo despues del banner.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">%run</code> ejecuta ese notebook dentro de esta misma sesion de Spark. Este es el <strong style="color:#e2e8f0;">unico</strong> lugar del curso con <code style="color:#38bdf8;">dbutils.widgets</code> — si necesitas cambiar el catalog, se edita alla, no aqui.</td>
#     </tr>
#   </table>
# </div>

# %%
# %run ../00_Setup/00_Configuracion

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA 1.2</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">Primer contacto con el workspace y Compute Serverless</h2>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border-left:4px solid #0d9488;padding:14px 16px;border-radius:6px;margin:10px 0;">
#   <span style="color:#0d9488;font-size:11px;font-weight:700;letter-spacing:1px;">COMPUTE SERVERLESS</span><br/>
#   <span style="color:#cbd5e1;font-size:13px;"><strong style="color:#e2e8f0;">Compute Serverless</strong> significa que este notebook nunca tuvo que esperar a que un cluster arrancara. Databricks aprovisiona el computo bajo demanda, por segundo de uso, y lo libera automaticamente al terminar. En Databricks Free Edition, Serverless es el <strong style="color:#e2e8f0;">unico</strong> tipo de compute disponible — no hay clusters clasicos que crear ni administrar, por eso este notebook (y todos los del curso) no tienen ninguna celda de configuracion de cluster.</span>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Imprime el catalog/schema por defecto de la sesion y lista los catalogs y schemas visibles en el workspace.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Es el primer "hola mundo" de Unity Catalog: confirmar que el catalog creado por el Setup (el valor del widget <code style="color:#38bdf8;">catalog_name</code>) realmente existe y es visible antes de intentar leer una tabla de el.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">spark.catalog.currentCatalog()</code>/<code style="color:#38bdf8;">currentDatabase()</code> son metodos del API de Python que consultan el contexto actual sin tocar datos. <code style="color:#38bdf8;">SHOW CATALOGS</code>/<code style="color:#38bdf8;">SHOW SCHEMAS</code> son DDL estandar de Unity Catalog.</td>
#     </tr>
#   </table>
# </div>

# %%
# Unity Catalog: navegacion basica
print("Catalog actual:", spark.catalog.currentCatalog())
print("Schema actual: ", spark.catalog.currentDatabase())

print("\nCatalogs visibles:")
display(spark.sql("SHOW CATALOGS"))

print("\nSchemas dentro de nuestro catalog de entrenamiento:")
display(spark.sql(f"SHOW SCHEMAS IN {CATALOG_NAME}"))

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Lee la tabla Bronze <code style="color:#38bdf8;">clientes</code> como un DataFrame y muestra sus primeras 10 filas.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Primer contacto real con datos del curso — confirma que el Setup escribio la tabla correctamente y da una idea concreta de sus columnas antes de transformarla en el Modulo 2.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">spark.table(nombre_completo)</code> devuelve un DataFrame <strong style="color:#e2e8f0;">perezoso</strong> (lazy): no lee nada del disco todavia. <code style="color:#38bdf8;">display()</code> es la funcion de Databricks (no de Spark puro) que fuerza la ejecucion y renderiza una tabla interactiva con boton de grafico incorporado.</td>
#     </tr>
#   </table>
# </div>

# %%
# Primer vistazo a una tabla Bronze — clientes
df_clientes = spark.table(tbl(SCHEMA_BRONZE, "clientes"))

print(f"Filas: {df_clientes.count():,}   Columnas: {len(df_clientes.columns)}")
display(df_clientes.limit(10))

# %% [markdown]
# ### Ejercicio 1.1 — Primera mirada de negocio
#
# Sin usar todavia `groupBy` en detalle (eso es Modulo 2), responde con `display()` y el explorador visual de resultados:
# 1. ¿Cuantos clientes hay por `segmento` (Nuevo / Recurrente / VIP)?
# 2. ¿Cuantos clientes hay por `ciudad`?
#
# Usa el boton de grafico debajo de `display()` para convertir el resultado en una barra — no hace falta escribir codigo de graficos todavia.

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Cuenta clientes por <code style="color:#38bdf8;">segmento</code> y ordena el resultado.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Responder la pregunta 1 del ejercicio y dar el primer numero de negocio del curso: cuantos clientes VIP/Recurrente/Nuevo hay.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">groupBy("segmento").count()</code> es una agregacion basica — se explica a fondo en el Modulo 2 (Tema 2.4); aqui solo se usa para explorar.</td>
#     </tr>
#   </table>
# </div>

# %%
display(df_clientes.groupBy("segmento").count().orderBy("segmento"))

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Cuenta clientes por <code style="color:#38bdf8;">ciudad</code>, de mayor a menor.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Responder la pregunta 2 del ejercicio.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;">Mismo patron que la celda anterior, cambiando la columna de agrupacion y ordenando descendente con <code style="color:#38bdf8;">F.desc()</code>.</td>
#     </tr>
#   </table>
# </div>

# %%
display(df_clientes.groupBy("ciudad").count().orderBy(F.desc("count")))

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA 1.3</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">ACID: la garantia que el Data Lake no tenia</h2>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Consulta el historial de versiones de la tabla <code style="color:#38bdf8;">clientes</code>.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">DESCRIBE HISTORY</code> es exclusivo de Delta Lake — no existe sobre Parquet plano. Confirmamos que la tabla que acabamos de leer ya tiene capacidad de auditoria/Time Travel desde que se genero, aunque el Modulo 3 es donde se explota a fondo.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;">Cada escritura Delta queda registrada como una version atomica en el <em>transaction log</em> (<code style="color:#38bdf8;">_delta_log/</code>). <code style="color:#38bdf8;">DESCRIBE HISTORY</code> lee ese log y lo devuelve como una tabla — sin escanear los datos.</td>
#     </tr>
#   </table>
# </div>

# %%
# La tabla que acabamos de leer ya es transaccional — Delta Lake, no Parquet plano
display(spark.sql(f"DESCRIBE HISTORY {tbl(SCHEMA_BRONZE, 'clientes')}"))

# %% [markdown]
# > **Punto de control:** la version 0 que ves arriba es la escritura que hizo el notebook de Setup. A partir de la Sesion 6 (Modulo 3) vamos a volver a esta misma tabla, modificarla, y usar el historial para viajar entre versiones.

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0f172a;border:1px solid #0d9488;padding:18px 16px;border-radius:10px;margin:20px 0;">
#   <div style="color:#0d9488;font-size:13px;font-weight:700;letter-spacing:1px;margin-bottom:16px;">CIERRE PARCIAL — CONTINUA EN LA SESION 2</div>
#   <div style="color:#cbd5e1;font-size:13px;line-height:1.7;">
# Hoy vimos: (1) por que el Lakehouse combina lo mejor del Data Warehouse y el Data Lake, (2) como se ve el workspace y Compute Serverless, (3) que nuestras tablas Bronze ya son transaccionales (ACID) desde que se crearon.<br/><br/>
#       En la <strong style="color:#e2e8f0;">Sesion 2</strong> cerramos el Modulo 1: notebooks de Databricks a fondo (magics, celdas mixtas), Catalog Explorer programatico, el namespace de 3 niveles de Unity Catalog, y Git folders para versionar este mismo curso.
#   </div>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d9488);height:3px;border-radius:2px;margin:20px 0 8px 0;"></div>
# <div style="box-sizing:border-box;width:100%;display:flex;justify-content:space-between;color:#64748b;font-size:12px;">
#   <span>Modulo 1 &middot; Sesion 1 &nbsp;&middot;&nbsp; Siguiente: <strong>Sesion 2 &mdash; 02_Entorno_UnityCatalog_GitFolders</strong></span>
# </div>
