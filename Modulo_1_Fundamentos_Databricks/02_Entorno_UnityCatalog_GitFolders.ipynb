# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(135deg,#0a2a6e 0%,#0d5c8a 45%,#0d9488 100%);padding:22px 18px 18px 18px;border-radius:12px 12px 0 0;">
#   <div style="display:flex;justify-content:space-between;align-items:flex-start;flex-wrap:wrap;gap:8px;">
#     <div style="flex:1;min-width:0;">
#       <span style="background:rgba(255,255,255,0.18);color:#a8f0e0;font-size:10px;letter-spacing:2px;padding:3px 10px;border-radius:20px;font-weight:600;">DATABRICKS &nbsp;&middot;&nbsp; MODULO 1 &nbsp;&middot;&nbsp; SESION 2</span>
#       <h1 style="color:#ffffff;font-size:21px;margin:10px 0 4px 0;font-weight:700;">Entorno de Trabajo (2/2) + Cierre del Modulo</h1>
#       <p style="color:#b2f0e8;font-size:13px;margin:0;">Semana 1 &middot; E-commerce: abandono de carrito y deteccion de fraude</p>
#     </div>
#     <div style="text-align:right;flex-shrink:0;">
#       <div style="color:#ffffff;font-size:15px;font-weight:800;">Uniandes</div>
#       <div style="color:#7de8d8;font-size:10px;margin-top:2px;">Educacion Continua &middot; Databricks 2026</div>
#     </div>
#   </div>
# </div>
# <div style="box-sizing:border-box;width:100%;background:#0f172a;padding:12px 18px;border-radius:0 0 12px 12px;margin-bottom:6px;">
#   <table style="width:100%;border-collapse:collapse;table-layout:fixed;">
#     <tr>
#       <td style="width:33%;padding:8px 10px 8px 0;border-right:1px solid #1e3a5f;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">OBJETIVO</div>
#         <div style="color:#e2e8f0;font-size:12px;">Dominar notebooks (magics, %run), navegar Unity Catalog programaticamente y entender Git folders</div>
#       </td>
#       <td style="width:33%;padding:8px 10px;border-right:1px solid #1e3a5f;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">PREREQUISITO</div>
#         <div style="color:#e2e8f0;font-size:12px;">Sesion 1 completada</div>
#       </td>
#       <td style="width:33%;padding:8px 0 8px 10px;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">EJECUCION</div>
#         <div style="color:#e2e8f0;font-size:12px;">Sesion 2 — clase en vivo, Databricks Free Edition</div>
#       </td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0f172a;padding:12px 18px;border-radius:0 0 12px 12px;margin-bottom:6px;">
#   <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:8px;">OBJETIVOS DE LA SESION</div>
#   <div style="display:flex;flex-wrap:wrap;gap:8px;">
#     <div style="flex:1;min-width:200px;background:#1e3a5f;padding:10px 12px;border-radius:8px;color:#93c5fd;font-size:12px;"><strong style="color:#e2e8f0;">Tema 1.4:</strong> Notebooks: magics %sql, %run y celdas de lenguaje mixto</div>
#     <div style="flex:1;min-width:200px;background:#1e3a5f;padding:10px 12px;border-radius:8px;color:#93c5fd;font-size:12px;"><strong style="color:#e2e8f0;">Tema 1.5:</strong> Catalog Explorer programatico: SHOW / DESCRIBE</div>
#     <div style="flex:1;min-width:200px;background:#1e3a5f;padding:10px 12px;border-radius:8px;color:#93c5fd;font-size:12px;"><strong style="color:#e2e8f0;">Tema 1.6:</strong> Unity Catalog: namespace catalog.schema.tabla</div>
#     <div style="flex:1;min-width:200px;background:#1e3a5f;padding:10px 12px;border-radius:8px;color:#93c5fd;font-size:12px;"><strong style="color:#e2e8f0;">Tema 1.7:</strong> Git folders: version control nativo para notebooks</div>
#   </div>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Hereda de nuevo <code style="color:#38bdf8;">CATALOG_NAME</code> y las demas variables de configuracion — cada notebook es independiente, aunque sea la continuacion directa del anterior.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Un notebook nuevo arranca con una sesion Python limpia: aunque la Sesion 1 ya corrio <code style="color:#38bdf8;">%run</code>, ese estado no cruza de un notebook a otro. Hay que repetirlo aqui.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;">Identico a la Sesion 1: <code style="color:#38bdf8;">%run ../00_Setup/00_Configuracion</code> como primera celda de codigo, siempre.</td>
#     </tr>
#   </table>
# </div>

# %%
# %run ../00_Setup/00_Configuracion

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA 1.4</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">Notebooks de Databricks: magics y celdas de lenguaje mixto</h2>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Convierte el DataFrame de <code style="color:#38bdf8;">eventos_carrito</code> en una <strong style="color:#e2e8f0;">vista temporal</strong> de SQL llamada <code style="color:#38bdf8;">eventos_carrito_tmp</code>.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Preparar el puente entre Python y SQL: la vista que se crea aqui en Python se va a consultar en la celda siguiente con <code style="color:#38bdf8;">%sql</code>, sin volver a tocar Python.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">createOrReplaceTempView()</code> registra el DataFrame como una tabla temporal <strong style="color:#e2e8f0;">solo visible en esta sesion de Spark</strong> (no queda persistida en Unity Catalog) — cualquier celda posterior del mismo notebook, sea Python o SQL, puede consultarla porque comparten el mismo <code style="color:#38bdf8;">SparkSession</code>.</td>
#     </tr>
#   </table>
# </div>

# %%
# Vista temporal — puente entre Python y SQL dentro del mismo notebook
spark.table(tbl(SCHEMA_BRONZE, "eventos_carrito")).createOrReplaceTempView("eventos_carrito_tmp")
print("Vista temporal creada: eventos_carrito_tmp (visible tambien desde celdas %sql)")

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Cuenta eventos por <code style="color:#38bdf8;">tipo_evento</code>, escrito en SQL puro.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Demostrar que el magic <code style="color:#38bdf8;">%sql</code> cambia el lenguaje de <strong style="color:#e2e8f0;">esa celda unicamente</strong> — el resto del notebook sigue siendo Python.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;">El magic <code style="color:#38bdf8;">%sql</code> debe ser la primera linea de la celda. A partir de ahi, todo el contenido se interpreta como Spark SQL — incluye la vista temporal creada en la celda anterior.</td>
#     </tr>
#   </table>
# </div>

# %%
# %sql
-- Celda 100% SQL dentro de un notebook Python: el magic %sql cambia el lenguaje de ESTA celda
SELECT tipo_evento, COUNT(*) AS eventos
FROM eventos_carrito_tmp
GROUP BY tipo_evento
ORDER BY eventos DESC

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Ejecuta dos comandos de shell dentro del notebook: version de Python instalada y un mensaje informativo.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Mostrar el tercer magic mas usado (<code style="color:#38bdf8;">%sh</code>) — util para inspeccionar el entorno del driver (por ejemplo, verificar una libreria instalada).</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">%sh</code> ejecuta el contenido de la celda como un script de shell <strong style="color:#e2e8f0;">en el nodo driver</strong>, no en los executors — por eso no sirve para procesar datos distribuidos, solo para tareas de sistema operativo.</td>
#     </tr>
#   </table>
# </div>

# %%
# %sh
# Celda 100% shell: util para inspeccionar el sistema de archivos del driver, no el Lakehouse
echo "Python:" && python3 --version
echo "Este comando corre en el driver, no en los executors — usarlo con moderacion"

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA 1.5</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">Catalog Explorer programatico</h2>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Obtiene el detalle extendido y el detalle fisico de la tabla <code style="color:#38bdf8;">clientes</code>.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Todo lo que muestra el panel visual <strong style="color:#e2e8f0;">Catalog Explorer</strong> tambien se puede consultar por SQL — util para automatizar validaciones (por ejemplo, un Job que falle si una tabla esperada no existe o pesa menos de lo esperado).</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">DESCRIBE TABLE EXTENDED</code> devuelve columnas, tipos y metadatos de owner/comment; <code style="color:#38bdf8;">DESCRIBE DETAIL</code> devuelve el detalle fisico (formato, numero de archivos, tamano, ubicacion) — el mismo contenido que la pestana "Details" del explorador visual.</td>
#     </tr>
#   </table>
# </div>

# %%
tabla_clientes = tbl(SCHEMA_BRONZE, "clientes")

print("DESCRIBE TABLE EXTENDED:")
display(spark.sql(f"DESCRIBE TABLE EXTENDED {tabla_clientes}"))

print("\nDESCRIBE DETAIL (equivalente a la pestana 'Details' del Catalog Explorer):")
display(spark.sql(f"DESCRIBE DETAIL {tabla_clientes}").select("format", "numFiles", "sizeInBytes", "location"))

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA 1.6</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">Unity Catalog: el namespace de 3 niveles</h2>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Fija el catalog y el schema por defecto de la sesion (<code style="color:#38bdf8;">USE CATALOG</code> / <code style="color:#38bdf8;">USE SCHEMA</code>) y consulta <code style="color:#38bdf8;">transacciones</code> sin calificar su nombre.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Unity Catalog organiza todo bajo <code style="color:#38bdf8;">catalog.schema.tabla</code> — el mismo patron que un DBA de SQL Server reconoce como <code style="color:#38bdf8;">base_datos.esquema.tabla</code>, con un nivel adicional pensado para separar ambientes completos (training/dev/prod) dentro del mismo workspace.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">USE CATALOG</code>/<code style="color:#38bdf8;">USE SCHEMA</code> cambian el contexto de resolucion de nombres <strong style="color:#e2e8f0;">de la sesion actual</strong> — a partir de esa celda, cualquier nombre sin calificar (<code style="color:#38bdf8;">transacciones</code> en vez de <code style="color:#38bdf8;">catalog.schema.transacciones</code>) se resuelve contra ese contexto.</td>
#     </tr>
#   </table>
# </div>

# %%
# Fijar el contexto por defecto de la sesion — a partir de aqui, nombres sin calificar
# resuelven contra este catalog y schema
spark.sql(f"USE CATALOG {CATALOG_NAME}")
spark.sql(f"USE SCHEMA {SCHEMA_BRONZE}")

print("Contexto actual:", spark.catalog.currentCatalog(), ".", spark.catalog.currentDatabase())
print("\nAhora 'transacciones' resuelve sin calificar, gracias a USE CATALOG / USE SCHEMA:")
display(spark.sql("SELECT COUNT(*) AS total_transacciones FROM transacciones"))

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA 1.7</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">Git folders: control de versiones para notebooks</h2>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border-left:4px solid #7c3aed;padding:14px 16px;border-radius:6px;margin:10px 0;">
#   <span style="color:#7c3aed;font-size:11px;font-weight:700;letter-spacing:1px;">GIT FOLDERS</span><br/>
#   <span style="color:#cbd5e1;font-size:13px;">Este curso completo vive en un repositorio Git, montado en el workspace como un <strong style="color:#e2e8f0;">Git folder</strong> (antes llamado "Repos") — disponible en Databricks Free Edition sin restricciones. Cada notebook es, por debajo, un archivo de texto plano (<code style="color:#38bdf8;">.py</code> con marcadores <code style="color:#38bdf8;">%md</code>/<code style="color:#38bdf8;">COMMAND ----------</code>, o <code style="color:#38bdf8;">.ipynb</code>) — eso es lo que permite hacer <code style="color:#38bdf8;">diff</code>, <code style="color:#38bdf8;">commit</code> y <code style="color:#38bdf8;">pull request</code> igual que con codigo de aplicacion. La estructura de carpetas que estas usando ahora mismo (<code style="color:#38bdf8;">00_Setup/</code>, <code style="color:#38bdf8;">Modulo_1.../</code> ... <code style="color:#38bdf8;">Modulo_6.../</code>) es exactamente el patron recomendado: un notebook de configuracion central y carpetas numeradas por modulo.</span>
# </div>

# %% [markdown]
# **Flujo tipico con Git folders en Databricks:**
# 1. `Workspace > Git folders > Add` — se clona el repositorio (como este) dentro del workspace.
# 2. Cada estudiante trabaja en su propia rama (`feature/nombre-apellido`) para no pisar el trabajo de otros.
# 3. Los cambios se confirman (`commit`) y se sincronizan (`push`) desde el mismo panel del notebook, sin salir de Databricks.
# 4. El proyecto final (Modulo 6, Sesiones 15-16) se entrega como un Pull Request sobre este mismo repositorio.

# %% [markdown]
# ### Ejercicio 1.2 — Inventario completo del catalog
#
# Cierre del modulo: construir el inventario de **todas** las tablas Bronze creadas en el Setup, con su conteo de registros y su formato. Este es el mismo patron que se usara al inicio de cada modulo siguiente para confirmar que el estado del Lakehouse es el esperado.

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Recorre los 3 schemas del catalog, lista sus tablas y suma registros/tamano total.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">El inventario es el punto de partida obligatorio de cualquier sesion de trabajo con datos: ¿que tablas existen?, ¿cuantos registros tienen?, ¿que tan pesadas son? Antes de escribir una sola transformacion (Modulo 2), conviene confirmar que el entorno esta completo.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;">Doble loop: <code style="color:#38bdf8;">SHOW TABLES IN catalog.schema</code> por cada schema, y dentro, <code style="color:#38bdf8;">count()</code> + <code style="color:#38bdf8;">DESCRIBE DETAIL</code> por cada tabla — acumulando totales en un diccionario Python simple.</td>
#     </tr>
#   </table>
# </div>

# %%
print("INVENTARIO DE OBJETOS —", CATALOG_NAME)
print("=" * 72)

resumen_total = {"tablas": 0, "registros": 0, "mb": 0.0}
for schema in [SCHEMA_BRONZE, SCHEMA_SILVER, SCHEMA_GOLD]:
    tablas = spark.sql(f"SHOW TABLES IN {CATALOG_NAME}.{schema}").collect()
    print(f"\n{schema.upper()} — {len(tablas)} tabla(s)")
    for t in tablas:
        full = f"{CATALOG_NAME}.{schema}.{t.tableName}"
        cnt = spark.table(full).count()
        det = spark.sql(f"DESCRIBE DETAIL {full}").first()
        mb  = (det["sizeInBytes"] or 0) / 1024 / 1024
        print(f"  {t.tableName:<20} {cnt:>10,} registros  {mb:>8.1f} MB  formato={det['format']}")
        resumen_total["tablas"] += 1
        resumen_total["registros"] += cnt
        resumen_total["mb"] += mb

print("\n" + "=" * 72)
print(f"TOTAL: {resumen_total['tablas']} tablas | {resumen_total['registros']:,} registros | {resumen_total['mb']:.1f} MB")
print("\nSolo BRONZE deberia tener tablas en este punto del curso — Silver y Gold llegan en los Modulos 2, 3 y 5.")

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0f172a;border:1px solid #0d9488;padding:18px 16px;border-radius:10px;margin:20px 0;">
#   <div style="color:#0d9488;font-size:13px;font-weight:700;letter-spacing:1px;margin-bottom:16px;">CIERRE DEL MODULO 1</div>
#   <div style="color:#cbd5e1;font-size:13px;line-height:1.7;">
# <strong style="color:#e2e8f0;">Temas 1.1 - 1.3 (Sesion 1):</strong> Lakehouse vs Data Warehouse/Data Lake, primer contacto con el workspace y Compute Serverless, ACID como garantia nueva del Data Lake.<br/>
#       <strong style="color:#e2e8f0;">Temas 1.4 - 1.7 (Sesion 2):</strong> magics y celdas de lenguaje mixto, Catalog Explorer programatico, namespace de 3 niveles de Unity Catalog, Git folders para versionar el curso.<br/><br/>
#       A partir del <strong style="color:#e2e8f0;">Modulo 2</strong> empezamos a <em>transformar</em> estos datos Bronze con PySpark y Spark SQL — el primer paso hacia la capa Silver.
#   </div>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d9488);height:3px;border-radius:2px;margin:20px 0 8px 0;"></div>
# <div style="box-sizing:border-box;width:100%;display:flex;justify-content:space-between;color:#64748b;font-size:12px;">
#   <span>Modulo 1 &middot; Sesion 2 &middot; Fin del Modulo 1 &nbsp;&middot;&nbsp; Siguiente: <strong>Modulo 2 &middot; Sesion 3 &mdash; Transformacion de datos a gran escala</strong></span>
# </div>
