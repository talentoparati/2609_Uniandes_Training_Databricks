# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(135deg,#0a2a6e 0%,#0d5c8a 45%,#0d9488 100%);padding:22px 18px 18px 18px;border-radius:12px 12px 0 0;">
#   <div style="display:flex;justify-content:space-between;align-items:flex-start;flex-wrap:wrap;gap:8px;">
#     <div style="flex:1;min-width:0;">
#       <span style="background:rgba(255,255,255,0.18);color:#a8f0e0;font-size:10px;letter-spacing:2px;padding:3px 10px;border-radius:20px;font-weight:600;">DATABRICKS &nbsp;&middot;&nbsp; MODULO 6 &nbsp;&middot;&nbsp; SESION 15</span>
#       <h1 style="color:#ffffff;font-size:21px;margin:10px 0 4px 0;font-weight:700;">Proyecto Final — Kickoff y Trabajo Guiado</h1>
#       <p style="color:#b2f0e8;font-size:13px;margin:0;">Semana 6 &middot; Cada estudiante define su propio caso de uso</p>
#     </div>
#     <div style="text-align:right;flex-shrink:0;">
#       <div style="color:#ffffff;font-size:15px;font-weight:800;">Uniandes</div>
#       <div style="color:#7de8d8;font-size:10px;margin-top:2px;">Educacion Continua &middot; Databricks 2026</div>
#     </div>
#   </div>
# </div>
# <div style="box-sizing:border-box;width:100%;background:#0f172a;padding:12px 18px;border-radius:0 0 12px 12px;margin-bottom:6px;">
#   <table style="width:100%;border-collapse:collapse;table-layout:fixed;">
#     <tr>
#       <td style="width:33%;padding:8px 10px 8px 0;border-right:1px solid #1e3a5f;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">OBJETIVO</div>
#         <div style="color:#e2e8f0;font-size:12px;">Definir el alcance del proyecto final y dejar el andamiaje (scaffold) del repositorio listo para trabajar</div>
#       </td>
#       <td style="width:33%;padding:8px 10px;border-right:1px solid #1e3a5f;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">PREREQUISITO</div>
#         <div style="color:#e2e8f0;font-size:12px;">Modulos 1 a 6 completados</div>
#       </td>
#       <td style="width:33%;padding:8px 0 8px 10px;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">EJECUCION</div>
#         <div style="color:#e2e8f0;font-size:12px;">Sesion 15 — trabajo guiado en clase</div>
#       </td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# ### El proyecto final
#
# Cada estudiante (o equipo) elige **su propio caso de uso** — no tiene que ser e-commerce — y construye, con datos propios o sinteticos, una version reducida de todo lo que se hizo en este curso sobre el caso del carrito de compras. El objetivo no es el tamano del dataset: es demostrar dominio de **cada capa de la arquitectura**. Todo debe seguir corriendo en Databricks Free Edition, igual que las 14 sesiones anteriores.

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA P.1</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">Rubrica del proyecto</h2>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0f172a;border-left:4px solid #0d9488;padding:14px 16px;border-radius:6px;margin:10px 0;">
#   <table style="color:#cbd5e1;font-size:12px;width:100%;border-collapse:collapse;">
#     <tr style="color:#64748b;font-size:10px;"><td style="padding:3px 10px 3px 0;">MODULO</td><td style="padding:3px 10px 3px 0;">QUE DEBE DEMOSTRARSE</td><td style="padding:3px 10px 3px 0;">EVIDENCIA</td><td style="padding:3px 10px 3px 0;">PESO</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:5px 10px 5px 0;color:#0d9488;font-weight:600;">M1-M2</td><td style="padding:5px 10px 5px 0;">Ingesta y transformacion</td><td style="padding:5px 10px 5px 0;">Notebook Setup con widgets + al menos 1 tabla Bronze y su limpieza a Silver (DataFrame API o SQL)</td><td style="padding:5px 10px 5px 0;">20%</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:5px 10px 5px 0;color:#0d9488;font-weight:600;">M3</td><td style="padding:5px 10px 5px 0;">Delta Lake</td><td style="padding:5px 10px 5px 0;">Uso de Time Travel o MERGE INTO, y al menos un OPTIMIZE justificado</td><td style="padding:5px 10px 5px 0;">20%</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:5px 10px 5px 0;color:#0d9488;font-weight:600;">M4</td><td style="padding:5px 10px 5px 0;">Gobernanza</td><td style="padding:5px 10px 5px 0;">Catalog propio con schemas Medallion, al menos un GRANT documentado</td><td style="padding:5px 10px 5px 0;">15%</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:5px 10px 5px 0;color:#0d9488;font-weight:600;">M5</td><td style="padding:5px 10px 5px 0;">Orquestacion</td><td style="padding:5px 10px 5px 0;">Un Job (aunque sea de 2 tasks) creado por SDK o UI, con dependencias</td><td style="padding:5px 10px 5px 0;">20%</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:5px 10px 5px 0;color:#0d9488;font-weight:600;">M6</td><td style="padding:5px 10px 5px 0;">Machine Learning</td><td style="padding:5px 10px 5px 0;">Un modelo entrenado con tracking en MLflow y registrado en Unity Catalog</td><td style="padding:5px 10px 5px 0;">25%</td></tr>
#   </table>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA P.2</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">Estructura de repositorio recomendada</h2>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border-left:4px solid #7c3aed;padding:14px 16px;border-radius:6px;margin:10px 0;">
#   <span style="color:#7c3aed;font-size:11px;font-weight:700;letter-spacing:1px;">GIT FOLDERS — TEMA 1.7</span><br/>
#   <span style="color:#cbd5e1;font-size:13px;">Se recomienda <strong style="color:#e2e8f0;">reutilizar exactamente la estructura de este curso</strong> (Modulo 1, Tema 1.7 — Git folders): un notebook central de configuracion con widgets, y una carpeta por bloque tematico. Un evaluador que ya conoce este patron puede navegar el proyecto de cualquier estudiante sin instrucciones adicionales.</span>
# </div>

# %% [markdown]
# ```
# Proyecto_Final_<Nombre>/
#   00_Setup/
#     00_Configuracion.ipynb          <- widgets: catalog_name, entorno, parametros propios
#     01_Generacion_o_Ingesta.ipynb
#   01_Exploracion_y_Transformacion.ipynb
#   02_Delta_Lake.ipynb
#   03_Gobernanza.ipynb
#   04_Orquestacion.ipynb
#   05_Machine_Learning.ipynb
# ```

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA P.3</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">Scaffold: adaptar la configuracion central a su propio proyecto</h2>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Declara los widgets minimos de un proyecto nuevo (catalog y entorno) y crea su catalog + schemas Medallion.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Es el mismo patron de <code style="color:#38bdf8;">00_Setup/00_Configuracion</code> usado en todo el curso, listo para copiar y adaptar: un catalog nuevo, propio del proyecto, para no interferir con <code style="color:#38bdf8;">ecommerce_training</code>.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;">Identico en estructura al notebook de configuracion del curso (Modulo 1): <code style="color:#38bdf8;">dbutils.widgets</code> primero, variables en mayusculas despues, <code style="color:#38bdf8;">CREATE CATALOG/SCHEMA IF NOT EXISTS</code> al final. Este bloque se copia tal cual como <code style="color:#38bdf8;">00_Setup/00_Configuracion.ipynb</code> del proyecto final.</td>
#     </tr>
#   </table>
# </div>

# %%
# Copiar este bloque como 00_Setup/00_Configuracion.ipynb del proyecto final
# (usar dbutils.widgets, NO variables sueltas — ver Modulo 1)

dbutils.widgets.text("catalog_name", "proyecto_final_<su_nombre>", "Catalog del proyecto")
dbutils.widgets.dropdown("entorno", "training", ["training", "dev", "demo"], "Entorno")

PROY_CATALOG = dbutils.widgets.get("catalog_name")
PROY_ENTORNO = dbutils.widgets.get("entorno")
PROY_SCHEMA_BRONZE, PROY_SCHEMA_SILVER, PROY_SCHEMA_GOLD = "bronze", "silver", "gold"

spark.sql(f"CREATE CATALOG IF NOT EXISTS {PROY_CATALOG} COMMENT 'Proyecto final — {PROY_ENTORNO}'")
for schema in [PROY_SCHEMA_BRONZE, PROY_SCHEMA_SILVER, PROY_SCHEMA_GOLD]:
    spark.sql(f"CREATE SCHEMA IF NOT EXISTS {PROY_CATALOG}.{schema}")
    print(f"[OK] {PROY_CATALOG}.{schema}")

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d5c8a);padding:10px 16px;border-radius:8px;margin:16px 0 8px 0;">
#   <span style="color:#7de8d8;font-size:10px;letter-spacing:2px;font-weight:600;">TEMA P.4</span>
#   <h2 style="color:#ffffff;font-size:20px;margin:4px 0 0 0;">Trabajo guiado — checkpoints de la sesion</h2>
# </div>

# %% [markdown]
# Durante esta sesion, el instructor circula por equipos resolviendo bloqueos. Puntos de control sugeridos para el resto de la clase:
#
# 1. **Minuto 0-20:** catalog y schemas del proyecto creados (bloque anterior ejecutado y adaptado).
# 2. **Minuto 20-60:** primera tabla Bronze cargada (real o sintetica) y su version Silver limpia.
# 3. **Minuto 60-90:** al menos una operacion Delta Lake (MERGE, time travel u OPTIMIZE) aplicada y justificada en una celda markdown "ANTES DE EJECUTAR ESTA CELDA" (el mismo formato QUE / PARA QUE / COMO usado en todo el curso).
# 4. **Cierre de la sesion:** cada equipo comparte en 1 frase cual es su variable objetivo para el modelo de ML de la Sesion 16.

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0f172a;border:1px solid #0d9488;padding:18px 16px;border-radius:10px;margin:20px 0;">
#   <div style="color:#0d9488;font-size:13px;font-weight:700;letter-spacing:1px;margin-bottom:16px;">SIGUIENTE PASO</div>
#   <div style="color:#cbd5e1;font-size:13px;line-height:1.7;">
# No hay cierre de modulo todavia — la Sesion 15 es trabajo guiado en clase. Cada equipo continua de forma autonoma con su Bronze &rarr; Silver &rarr; Gold &rarr; ML hasta la <strong style="color:#e2e8f0;">Sesion 16</strong>, donde se expone el resultado y se cierra el curso con Model Registry y Model Serving sobre el modelo del Modulo 6 (Sesion 14) como referencia.
#   </div>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d9488);height:3px;border-radius:2px;margin:20px 0 8px 0;"></div>
# <div style="box-sizing:border-box;width:100%;display:flex;justify-content:space-between;color:#64748b;font-size:12px;">
#   <span>Modulo 6 &middot; Sesion 15 &nbsp;&middot;&nbsp; Siguiente: <strong>Sesion 16 &mdash; Exposicion final, Model Registry y Model Serving</strong></span>
# </div>
