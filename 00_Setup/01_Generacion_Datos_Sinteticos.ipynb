# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(135deg,#0a2a6e 0%,#0d5c8a 45%,#0d9488 100%);padding:22px 18px 18px 18px;border-radius:12px 12px 0 0;">
#   <div style="display:flex;justify-content:space-between;align-items:flex-start;flex-wrap:wrap;gap:8px;">
#     <div style="flex:1;min-width:0;">
#       <span style="background:rgba(255,255,255,0.18);color:#a8f0e0;font-size:10px;letter-spacing:2px;padding:3px 10px;border-radius:20px;font-weight:600;">DATABRICKS &nbsp;&middot;&nbsp; SETUP</span>
#       <h1 style="color:#ffffff;font-size:21px;margin:10px 0 4px 0;font-weight:700;">Generacion de Datos Sinteticos del Curso</h1>
#       <p style="color:#b2f0e8;font-size:13px;margin:0;">Catalog, schemas Medallion y dataset de E-commerce: abandono de carrito y deteccion de fraude</p>
#     </div>
#     <div style="text-align:right;flex-shrink:0;">
#       <div style="color:#ffffff;font-size:15px;font-weight:800;">Uniandes</div>
#       <div style="color:#7de8d8;font-size:10px;margin-top:2px;">Educacion Continua &middot; Databricks 2026</div>
#     </div>
#   </div>
# </div>
# <div style="box-sizing:border-box;width:100%;background:#0f172a;padding:12px 18px;border-radius:0 0 12px 12px;margin-bottom:6px;">
#   <table style="width:100%;border-collapse:collapse;table-layout:fixed;">
#     <tr>
#       <td style="width:33%;padding:8px 10px 8px 0;border-right:1px solid #1e3a5f;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">OBJETIVO</div>
#         <div style="color:#e2e8f0;font-size:12px;">Crear el catalog, los 3 schemas Medallion y las 5 tablas Bronze que usaran los 16 notebooks del curso</div>
#       </td>
#       <td style="width:33%;padding:8px 10px;border-right:1px solid #1e3a5f;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">PREREQUISITO</div>
#         <div style="color:#e2e8f0;font-size:12px;">Workspace Databricks Free Edition (Unity Catalog viene habilitado por defecto)</div>
#       </td>
#       <td style="width:33%;padding:8px 0 8px 10px;vertical-align:top;">
#         <div style="color:#64748b;font-size:10px;letter-spacing:1px;margin-bottom:3px;">EJECUCION</div>
#         <div style="color:#e2e8f0;font-size:12px;">Una sola vez, antes de la Sesion 1. Es idempotente: se puede re-ejecutar sin duplicar datos</div>
#       </td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0f172a;border-left:4px solid #0d9488;padding:14px 16px;border-radius:6px;margin:10px 0;">
#   <div style="color:#0d9488;font-size:10px;letter-spacing:1.5px;font-weight:600;margin-bottom:8px;">MAPA DEL CURSO</div>
#   <table style="color:#cbd5e1;font-size:12px;width:100%;border-collapse:collapse;">
#     <tr style="color:#64748b;font-size:10px;"><td style="padding:3px 10px 3px 0;">MODULO</td><td style="padding:3px 10px;">CONTENIDO</td><td style="padding:3px 10px;">SESIONES</td><td style="padding:3px 0 3px 10px;">TEMAS CLAVE</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:6px 10px 6px 0;color:#0d9488;font-weight:700;">M1</td><td style="padding:6px 10px;color:#e2e8f0;">Fundamentos de Databricks</td><td style="padding:6px 10px;color:#64748b;">Sesiones 1-2</td><td style="padding:6px 0 6px 10px;color:#93c5fd;">Lakehouse, entorno de trabajo, Unity Catalog (intro), Git folders</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:6px 10px 6px 0;color:#0d9488;font-weight:700;">M2</td><td style="padding:6px 10px;color:#e2e8f0;">Procesamiento con Apache Spark</td><td style="padding:6px 10px;color:#64748b;">Sesiones 3-5</td><td style="padding:6px 0 6px 10px;color:#93c5fd;">PySpark DataFrame API, Spark SQL, joins, ventanas, tuning</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:6px 10px 6px 0;color:#0d9488;font-weight:700;">M3</td><td style="padding:6px 10px;color:#e2e8f0;">Almacenamiento</td><td style="padding:6px 10px;color:#64748b;">Sesiones 6-8</td><td style="padding:6px 0 6px 10px;color:#93c5fd;">Delta Lake (ACID, time travel, MERGE, OPTIMIZE, ZORDER), DLT, Auto Loader</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:6px 10px 6px 0;color:#0d9488;font-weight:700;">M4</td><td style="padding:6px 10px;color:#e2e8f0;">Gobernanza</td><td style="padding:6px 10px;color:#64748b;">Sesiones 9-10</td><td style="padding:6px 0 6px 10px;color:#93c5fd;">Unity Catalog: permisos, linaje, auditoria</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:6px 10px 6px 0;color:#0d9488;font-weight:700;">M5</td><td style="padding:6px 10px;color:#e2e8f0;">Ingenieria de Datos</td><td style="padding:6px 10px;color:#64748b;">Sesiones 11-13</td><td style="padding:6px 0 6px 10px;color:#93c5fd;">Workflows, Lakeflow Declarative Pipelines, orquestacion, alertas</td></tr>
#     <tr style="border-top:1px solid #1e3a5f;"><td style="padding:6px 10px 6px 0;color:#0d9488;font-weight:700;">M6</td><td style="padding:6px 10px;color:#e2e8f0;">Machine Learning</td><td style="padding:6px 10px;color:#64748b;">Sesiones 14-16</td><td style="padding:6px 0 6px 10px;color:#93c5fd;">MLflow, Feature Engineering, Model Registry, Model Serving, proyecto final</td></tr>
#   </table>
# </div>

# %% [markdown]
# ### El caso de negocio
#
# Durante las 16 sesiones del curso trabajaremos sobre **un unico caso**: una tienda de e-commerce que quiere (1) entender por que los usuarios abandonan el carrito antes de pagar y (2) detectar transacciones fraudulentas antes de que se completen. Cada modulo agrega una capa de la arquitectura Medallion sobre el mismo dataset:
#
# | Entidad | Capa | Para que sirve |
# |---|---|---|
# | `clientes` | Bronze | Dimension de clientes — CRM |
# | `productos` | Bronze | Dimension de catalogo — ERP de inventario |
# | `sesiones_web` | Bronze | Una fila por sesion de navegacion — Web Analytics |
# | `eventos_carrito` | Bronze | Clickstream: view / add\_to\_cart / checkout / purchase |
# | `transacciones` | Bronze | Pagos, con una senal sintetica de fraude (`es_fraude`) |
#
# Este notebook solo crea la capa **Bronze** (datos tal como llegan del origen). Silver y Gold se construyen en vivo durante los Modulos 2, 3 y 5.

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border-left:4px solid #0d9488;padding:14px 16px;border-radius:6px;margin:10px 0;">
#   <span style="color:#0d9488;font-size:11px;font-weight:700;letter-spacing:1px;">COMPATIBILIDAD — DATABRICKS FREE EDITION</span><br/>
#   <span style="color:#cbd5e1;font-size:13px;">Este curso fue disenado y probado para correr <strong style="color:#e2e8f0;">100% en Databricks Free Edition</strong>: solo usa Compute Serverless (no clusters clasicos), 1 SQL Warehouse 2X-Small, Unity Catalog por defecto y Jobs con hasta 5 tasks concurrentes — exactamente los limites de la capa gratuita. Ningun notebook requiere una feature de pago.</span>
# </div>

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Ejecuta el notebook <code style="color:#38bdf8;">00_Configuracion</code> y trae sus variables (<code style="color:#38bdf8;">CATALOG_NAME</code>, <code style="color:#38bdf8;">SCHEMA_BRONZE/SILVER/GOLD</code>, <code style="color:#38bdf8;">NUM_CLIENTES</code>, <code style="color:#38bdf8;">SEED</code>, la funcion <code style="color:#38bdf8;">tbl()</code>, etc.) al contexto de este notebook.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Para que este notebook <strong style="color:#e2e8f0;">no</strong> defina ni un solo valor de configuracion por su cuenta — es el mismo principio del Modulo 1: un unico lugar de verdad (<code style="color:#38bdf8;">00_Setup</code>) del que heredan los 16 notebooks del curso.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">%run</code> ejecuta el notebook indicado dentro de la <strong style="color:#e2e8f0;">misma sesion de Spark</strong> y deja todas sus variables Python disponibles aqui, como si se hubieran escrito en esta misma celda — a diferencia de un <code style="color:#38bdf8;">import</code> de Python, comparte el mismo <code style="color:#38bdf8;">SparkSession</code> y el mismo <code style="color:#38bdf8;">spark</code>/<code style="color:#38bdf8;">dbutils</code>.</td>
#     </tr>
#   </table>
# </div>

# %%
# %run ../00_Setup/00_Configuracion

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Crea el catalog del curso, los 3 schemas de la Arquitectura Medallion (<code style="color:#38bdf8;">bronze</code>, <code style="color:#38bdf8;">silver</code>, <code style="color:#38bdf8;">gold</code>) y un <strong style="color:#e2e8f0;">Volume</strong> llamado <code style="color:#38bdf8;">landing</code>.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Unity Catalog exige la jerarquia <code style="color:#38bdf8;">catalog &rarr; schema &rarr; tabla</code> antes de poder escribir un solo dato. Cada schema Medallion tiene un proposito y, mas adelante (Modulo 4), permisos distintos. El Volume es donde los Modulos 3 y 5 simularan archivos llegando para Auto Loader.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">spark.sql()</code> ejecuta sentencias DDL estandar: <code style="color:#38bdf8;">CREATE CATALOG/SCHEMA/VOLUME IF NOT EXISTS</code>. <code style="color:#38bdf8;">IF NOT EXISTS</code> hace todo el bloque <strong style="color:#e2e8f0;">idempotente</strong>: volver a ejecutar este notebook no falla ni duplica objetos.</td>
#     </tr>
#   </table>
# </div>

# %%
# CREATE CATALOG y schemas Medallion + Volume de aterrizaje para Auto Loader
# IF NOT EXISTS hace el script idempotente — se puede re-ejecutar sin errores

spark.sql(f"CREATE CATALOG IF NOT EXISTS {CATALOG_NAME} COMMENT 'Catalog de entrenamiento — Uniandes / Databricks 2026'")

comentarios = {
    SCHEMA_BRONZE: "Ingesta cruda. Datos tal como vienen del sistema origen. Inmutable.",
    SCHEMA_SILVER: "Datos limpios, tipados y validados. Listos para analisis.",
    SCHEMA_GOLD:   "Agregaciones y KPIs. Consumido por BI, alertas y modelos ML."
}
for schema, comentario in comentarios.items():
    spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG_NAME}.{schema} COMMENT '{comentario}'")
    print(f"[OK] {CATALOG_NAME}.{schema:<8} -> {comentario}")

spark.sql(f"""
    CREATE VOLUME IF NOT EXISTS {tbl(SCHEMA_BRONZE, VOLUME_LANDING)}
    COMMENT 'Zona de aterrizaje para Auto Loader — Modulos 3 y 5'
""")
print(f"\n[OK] Volume creado: {tbl(SCHEMA_BRONZE, VOLUME_LANDING)}")

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Genera el DataFrame sintetico de <code style="color:#38bdf8;">clientes</code>: identificador, nombre, email, ciudad, pais, segmento, dispositivo preferido, fecha de registro y estado activo.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Es la dimension principal del curso — casi todas las tablas siguientes (sesiones, eventos, transacciones) se relacionan con <code style="color:#38bdf8;">cliente_id</code>.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">spark.range(1, N+1)</code> crea un DataFrame distribuido de N filas sin traer nada al driver. Cada <code style="color:#38bdf8;">withColumn</code> agrega una columna calculada por <strong style="color:#e2e8f0;">expresion vectorizada</strong> (<code style="color:#38bdf8;">F.element_at</code> sobre un array literal para simular categorias, <code style="color:#38bdf8;">F.rand(SEED)</code> para aleatoriedad reproducible). No hay loops Python: Spark distribuye el calculo entre executors — el mismo paradigma declarativo del Modulo 1.</td>
#     </tr>
#   </table>
# </div>

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import *

NUM_PRODUCTOS = 600  # dimension pequena — no depende de un widget

# TABLA 1: clientes — dimension principal, cargada desde el CRM
ciudades    = ["Bogota", "Medellin", "Cali", "Barranquilla", "Bucaramanga", "Cartagena"]
paises      = ["CO", "MX", "PE", "CL", "AR"]
segmentos   = ["Nuevo", "Recurrente", "VIP"]
dispositivos = ["Mobile", "Desktop", "Tablet"]

df_clientes = (
    spark.range(1, NUM_CLIENTES + 1)
    .withColumn("cliente_id", F.col("id").cast(IntegerType()))
    .withColumn("nombre",     F.concat(F.lit("Cliente_"), F.lpad(F.col("id").cast(StringType()), 6, "0")))
    .withColumn("email",      F.concat(F.lit("cliente"), F.col("id").cast(StringType()), F.lit("@correo-demo.com")))
    .withColumn("ciudad",     F.element_at(F.array(*[F.lit(c) for c in ciudades]),    (F.col("id") % 6 + 1).cast(IntegerType())))
    .withColumn("pais",       F.element_at(F.array(*[F.lit(p) for p in paises]),      (F.col("id") % 5 + 1).cast(IntegerType())))
    .withColumn("segmento",   F.element_at(F.array(*[F.lit(s) for s in segmentos]),   (F.col("id") % 3 + 1).cast(IntegerType())))
    .withColumn("dispositivo_preferido", F.element_at(F.array(*[F.lit(d) for d in dispositivos]), (F.col("id") % 3 + 1).cast(IntegerType())))
    .withColumn("fecha_registro", F.date_add(F.lit("2021-01-01").cast(DateType()), (F.col("id") * 3 % 1460).cast(IntegerType())))
    .withColumn("activo",     F.rand(SEED) > 0.05)
    .withColumn("ingested_at", F.current_timestamp())
    .withColumn("_source_system", F.lit("CRM_ECOMMERCE"))
    .drop("id")
)
print(f"Clientes generados: {df_clientes.count():,}")
display(df_clientes)

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Genera el DataFrame sintetico de <code style="color:#38bdf8;">productos</code>: catalogo con categoria, marca, precio y stock.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Dimension pequena que el Modulo 2 va a unir (join) contra el clickstream para saber que categoria/marca se abandona mas.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;">Mismo patron que <code style="color:#38bdf8;">clientes</code>: <code style="color:#38bdf8;">spark.range()</code> + columnas por expresion. Al ser solo 600 filas, esta tabla es la candidata natural para <em>broadcast joins</em> en el Modulo 2.</td>
#     </tr>
#   </table>
# </div>

# %%
# TABLA 2: productos — dimension de catalogo, cargada desde el ERP de inventario
categorias = ["Electronica", "Hogar", "Moda", "Deportes", "Belleza", "Juguetes"]
marcas     = ["MarcaA", "MarcaB", "MarcaC", "MarcaD", "MarcaE"]

df_productos = (
    spark.range(1, NUM_PRODUCTOS + 1)
    .withColumn("producto_id", F.col("id").cast(IntegerType()))
    .withColumn("nombre",      F.concat(F.lit("Producto_"), F.lpad(F.col("id").cast(StringType()), 4, "0")))
    .withColumn("categoria",   F.element_at(F.array(*[F.lit(c) for c in categorias]), (F.col("id") % 6 + 1).cast(IntegerType())))
    .withColumn("marca",       F.element_at(F.array(*[F.lit(m) for m in marcas]),     (F.col("id") % 5 + 1).cast(IntegerType())))
    .withColumn("precio",      (F.rand(SEED + 1) * 480000 + 20000).cast(DecimalType(10, 2)))
    .withColumn("stock",       (F.rand(SEED + 2) * 500).cast(IntegerType()))
    .withColumn("ingested_at", F.current_timestamp())
    .withColumn("_source_system", F.lit("ERP_INVENTARIO"))
    .drop("id")
)
print(f"Productos generados: {df_productos.count():,}")
display(df_productos)

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Genera <code style="color:#38bdf8;">sesiones_web</code>: una fila por sesion de navegacion, con canal de adquisicion, dispositivo, pais de IP y duracion.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Es el contenedor de cada visita: el Modulo 2 va a contar, por sesion, cuantas llegaron a <code style="color:#38bdf8;">add_to_cart</code> y cuantas a <code style="color:#38bdf8;">purchase</code> — la base del analisis de abandono de carrito.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">fecha_inicio</code> se construye sumando segundos aleatorios (<code style="color:#38bdf8;">F.rand()</code>) a una fecha base — asi cada sesion tiene una marca de tiempo distinta dentro del dia, sin usar ningun loop. <code style="color:#38bdf8;">fecha</code> (solo la parte de dia) queda lista para particionar la tabla.</td>
#     </tr>
#   </table>
# </div>

# %%
# TABLA 3: sesiones_web — una fila por sesion de navegacion (Web Analytics)
canales = ["Organico", "Pagado", "Email", "Social", "Directo"]

df_sesiones = (
    spark.range(1, NUM_SESIONES + 1)
    .withColumn("sesion_id",  F.concat(F.lit("SES-"), F.lpad(F.col("id").cast(StringType()), 7, "0")))
    .withColumn("cliente_id", (F.col("id") % NUM_CLIENTES + 1).cast(IntegerType()))
    .withColumn("_fecha_base", F.date_add(F.lit("2024-01-01").cast(DateType()), (F.col("id") % 365).cast(IntegerType())))
    .withColumn("fecha_inicio",
        (F.col("_fecha_base").cast("timestamp").cast("long") + (F.rand(SEED + 3) * 86400).cast("long")).cast("timestamp"))
    .withColumn("canal_origen", F.element_at(F.array(*[F.lit(c) for c in canales]),      (F.col("id") % 5 + 1).cast(IntegerType())))
    .withColumn("dispositivo",  F.element_at(F.array(*[F.lit(d) for d in dispositivos]), (F.col("id") % 3 + 1).cast(IntegerType())))
    .withColumn("pais_ip",      F.element_at(F.array(*[F.lit(p) for p in paises]),       (F.col("id") % 5 + 1).cast(IntegerType())))
    .withColumn("duracion_seg", (F.rand(SEED + 4) * 900 + 15).cast(IntegerType()))
    .withColumn("fecha", F.to_date("fecha_inicio"))
    .withColumn("ingested_at", F.current_timestamp())
    .withColumn("_source_system", F.lit("WEB_ANALYTICS"))
    .drop("id", "_fecha_base")
)
print(f"Sesiones generadas: {df_sesiones.count():,}")
display(df_sesiones)

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Genera <code style="color:#38bdf8;">eventos_carrito</code>: el clickstream — ~3 eventos por sesion en promedio, cada uno de un tipo (<code style="color:#38bdf8;">view_product</code>, <code style="color:#38bdf8;">add_to_cart</code>, <code style="color:#38bdf8;">remove_from_cart</code>, <code style="color:#38bdf8;">begin_checkout</code>, <code style="color:#38bdf8;">purchase</code>).</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Es la tabla central del caso de negocio: sin ella no existe "embudo de conversion" que medir en el Modulo 2.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;">Se genera una columna auxiliar <code style="color:#38bdf8;">_r</code> con un numero aleatorio uniforme (0 a 1) y una cascada de <code style="color:#38bdf8;">F.when()</code> que la traduce en <code style="color:#38bdf8;">tipo_evento</code> respetando las proporciones de un embudo real (55% vistas, bajando hasta 6% compras). Es el mismo patron declarativo de las tablas anteriores — sin loops.</td>
#     </tr>
#   </table>
# </div>

# %%
# TABLA 4: eventos_carrito — clickstream. ~3 eventos promedio por sesion.
# La distribucion de tipo_evento simula el embudo real de un e-commerce:
# view_product (55%) -> add_to_cart (25%) -> remove_from_cart (5%) -> begin_checkout (9%) -> purchase (6%)

NUM_EVENTOS = NUM_SESIONES * 3

df_eventos_carrito = (
    spark.range(1, NUM_EVENTOS + 1)
    .withColumn("evento_id",   F.col("id"))
    .withColumn("sesion_id",   F.concat(F.lit("SES-"), F.lpad((F.col("id") % NUM_SESIONES + 1).cast(StringType()), 7, "0")))
    .withColumn("cliente_id",  (F.col("id") % NUM_CLIENTES + 1).cast(IntegerType()))
    .withColumn("producto_id", (F.col("id") % NUM_PRODUCTOS + 1).cast(IntegerType()))
    .withColumn("_r", F.rand(SEED + 5))
    .withColumn("tipo_evento",
        F.when(F.col("_r") < 0.55, F.lit("view_product"))
         .when(F.col("_r") < 0.80, F.lit("add_to_cart"))
         .when(F.col("_r") < 0.85, F.lit("remove_from_cart"))
         .when(F.col("_r") < 0.94, F.lit("begin_checkout"))
         .otherwise(F.lit("purchase")))
    .withColumn("cantidad",         (F.rand(SEED + 6) * 3 + 1).cast(IntegerType()))
    .withColumn("precio_unitario",  (F.rand(SEED + 7) * 480000 + 20000).cast(DecimalType(10, 2)))
    .withColumn("_fecha_base", F.date_add(F.lit("2024-01-01").cast(DateType()), (F.col("id") % 365).cast(IntegerType())))
    .withColumn("event_timestamp",
        (F.col("_fecha_base").cast("timestamp").cast("long") + (F.rand(SEED + 8) * 86400).cast("long")).cast("timestamp"))
    .withColumn("fecha", F.to_date("event_timestamp"))
    .withColumn("ingested_at", F.current_timestamp())
    .withColumn("_source_system", F.lit("WEB_ANALYTICS"))
    .drop("id", "_r", "_fecha_base")
)
print(f"Eventos de carrito generados: {df_eventos_carrito.count():,}")
display(df_eventos_carrito.groupBy("tipo_evento").count().orderBy(F.desc("count")))

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Genera <code style="color:#38bdf8;">transacciones</code>: pagos con una senal sintetica de fraude (<code style="color:#38bdf8;">es_fraude</code>) que sera la variable objetivo del Modulo 6.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Sin una etiqueta de fraude no hay forma de entrenar ni evaluar un modelo supervisado en el Modulo 6 — se construye aqui para que exista desde el dia 1 del curso.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;">Se combinan tres senales de riesgo realistas en un <code style="color:#38bdf8;">_score_riesgo</code> ponderado: pais de IP distinto al del cliente (peso 0.5), monto atipicamente alto (peso 0.3) y horario inusual — antes de 5am o despues de 11pm (peso 0.2) — mas un componente aleatorio. <code style="color:#38bdf8;">es_fraude</code> es simplemente ese score superando un umbral. Es exactamente el tipo de combinacion de senales que se llamara "feature engineering" cuando se formalice en el Modulo 6.</td>
#     </tr>
#   </table>
# </div>

# %%
# TABLA 5: transacciones — pagos, con senal sintetica de fraude para el Modulo 6
metodos = ["Tarjeta_Credito", "Tarjeta_Debito", "PSE", "Wallet"]

df_transacciones = (
    spark.range(1, NUM_TRANSACCIONES + 1)
    .withColumn("transaccion_id", F.col("id"))
    .withColumn("cliente_id", (F.col("id") % NUM_CLIENTES + 1).cast(IntegerType()))
    .withColumn("sesion_id",  F.concat(F.lit("SES-"), F.lpad((F.col("id") % NUM_SESIONES + 1).cast(StringType()), 7, "0")))
    .withColumn("_fecha_base", F.date_add(F.lit("2024-01-01").cast(DateType()), (F.col("id") % 365).cast(IntegerType())))
    .withColumn("fecha_transaccion",
        (F.col("_fecha_base").cast("timestamp").cast("long") + (F.rand(SEED + 9) * 86400).cast("long")).cast("timestamp"))
    .withColumn("monto_total",  (F.rand(SEED + 10) * 950000 + 30000).cast(DecimalType(12, 2)))
    .withColumn("metodo_pago",  F.element_at(F.array(*[F.lit(m) for m in metodos]),      (F.col("id") % 4 + 1).cast(IntegerType())))
    .withColumn("dispositivo",  F.element_at(F.array(*[F.lit(d) for d in dispositivos]), (F.col("id") % 3 + 1).cast(IntegerType())))
    .withColumn("pais_cliente", F.element_at(F.array(*[F.lit(p) for p in paises]),       (F.col("id") % 5 + 1).cast(IntegerType())))
    # pais_ip distinto al pais del cliente en ~8% de los casos -> senal de riesgo
    .withColumn("pais_ip_transaccion",
        F.when(F.rand(SEED + 11) < 0.08,
               F.element_at(F.array(*[F.lit(p) for p in paises]), ((F.col("id") + 2) % 5 + 1).cast(IntegerType())))
         .otherwise(F.col("pais_cliente")))
    .withColumn("_hora", F.hour("fecha_transaccion"))
    .withColumn("_senal_pais",    (F.col("pais_ip_transaccion") != F.col("pais_cliente")).cast(IntegerType()))
    .withColumn("_senal_monto",   (F.col("monto_total") > 700000).cast(IntegerType()))
    .withColumn("_senal_horario", ((F.col("_hora") < 5) | (F.col("_hora") > 23)).cast(IntegerType()))
    .withColumn("_score_riesgo",
        F.col("_senal_pais") * F.lit(0.5) + F.col("_senal_monto") * F.lit(0.3) +
        F.col("_senal_horario") * F.lit(0.2) + F.rand(SEED + 12) * F.lit(0.3))
    .withColumn("es_fraude", F.col("_score_riesgo") > 0.65)
    .withColumn("estado",
        F.when(F.col("es_fraude"), F.lit("Reembolsada"))
         .when(F.rand(SEED + 13) < 0.06, F.lit("Fallida"))
         .otherwise(F.lit("Completada")))
    .withColumn("fecha", F.to_date("fecha_transaccion"))
    .withColumn("ingested_at", F.current_timestamp())
    .withColumn("_source_system", F.lit("PAYMENTS_GATEWAY"))
    .drop("id", "_fecha_base", "_hora", "_senal_pais", "_senal_monto", "_senal_horario", "_score_riesgo")
)
print(f"Transacciones generadas: {df_transacciones.count():,}")
display(df_transacciones.groupBy("es_fraude", "estado").count().orderBy(F.desc("count")))

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Define una funcion reutilizable <code style="color:#38bdf8;">escribir_bronze()</code> y la usa para persistir las 5 tablas generadas como Delta en el schema <code style="color:#38bdf8;">bronze</code>.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Persistir en formato <strong style="color:#e2e8f0;">Delta Lake</strong> (no Parquet plano) habilita, desde este mismo momento, ACID y Time Travel (Modulo 3). Particionar por <code style="color:#38bdf8;">fecha</code> acelera todo el analisis posterior que filtra por rango de fechas.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">df.write.format("delta").mode("overwrite").saveAsTable(...)</code> es la forma estandar de escribir una tabla administrada en Unity Catalog. <code style="color:#38bdf8;">partitionBy("fecha")</code> solo se aplica a las tablas con columna de fecha; <code style="color:#38bdf8;">overwriteSchema=true</code> permite re-ejecutar el notebook si el esquema cambia, sin fallar.</td>
#     </tr>
#   </table>
# </div>

# %%
# Funcion de escritura reutilizable — patron DRY (Don't Repeat Yourself)
def escribir_bronze(df, tabla, comment, partition_col=None):
    full_name = tbl(SCHEMA_BRONZE, tabla)
    writer = (
        df.write.format("delta")
          .mode("overwrite")
          .option("overwriteSchema", "true")
          .option("delta.autoOptimize.optimizeWrite", "true")  # archivos de tamano optimo al escribir
    )
    if partition_col:
        writer = writer.partitionBy(partition_col)
    writer.saveAsTable(full_name)
    spark.sql(f"COMMENT ON TABLE {full_name} IS '{comment}'")
    print(f"[OK] {full_name} — {spark.table(full_name).count():,} registros")

escribir_bronze(df_clientes,        "clientes",        "Clientes — dimension principal (CRM)")
escribir_bronze(df_productos,       "productos",       "Catalogo de productos (ERP Inventario)")
escribir_bronze(df_sesiones,        "sesiones_web",     "Sesiones de navegacion (Web Analytics)",  partition_col="fecha")
escribir_bronze(df_eventos_carrito, "eventos_carrito",  "Clickstream del carrito de compras",      partition_col="fecha")
escribir_bronze(df_transacciones,   "transacciones",    "Pagos, con senal sintetica de fraude",    partition_col="fecha")

print("\nSetup completado. Proceda con el Modulo 1 — Sesion 1.")

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:#0c1a2e;border:1px solid #1e3a5f;border-left:4px solid #2563eb;border-radius:6px;margin:10px 0;overflow:hidden;">
#   <div style="padding:8px 16px;border-bottom:1px solid #1e3a5f;background:rgba(37,99,235,0.08);">
#     <span style="color:#38bdf8;font-size:10px;font-weight:700;letter-spacing:1.5px;">ANTES DE EJECUTAR ESTA CELDA</span>
#   </div>
#   <table style="width:100%;border-collapse:collapse;">
#     <tr>
#       <td style="width:78px;padding:8px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">QUE HACE</td>
#       <td style="padding:8px 16px 6px 0;color:#e2e8f0;font-size:13px;">Recorre los 3 schemas, cuenta registros y formato de cada tabla, y calcula dos metricas de negocio: tasa <code style="color:#38bdf8;">add_to_cart &rarr; purchase</code> y tasa de fraude.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 6px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">PARA QUE</td>
#       <td style="padding:6px 16px 6px 0;color:#93c5fd;font-size:13px;">Confirmar que el entorno quedo completo <strong style="color:#e2e8f0;">antes</strong> de empezar la Sesion 1 evita que los 16 notebooks siguientes fallen con errores confusos de "tabla no encontrada" a mitad de una clase en vivo.</td>
#     </tr>
#     <tr>
#       <td style="padding:6px 4px 10px 16px;vertical-align:top;color:#64748b;font-size:10px;letter-spacing:1px;white-space:nowrap;">COMO LO HACE</td>
#       <td style="padding:6px 16px 10px 0;color:#93c5fd;font-size:13px;"><code style="color:#38bdf8;">SHOW TABLES</code> + <code style="color:#38bdf8;">DESCRIBE DETAIL</code> por schema (metadatos, no escanean los datos); los conteos de negocio si hacen un <code style="color:#38bdf8;">count()</code>/<code style="color:#38bdf8;">filter()</code> sobre las tablas ya escritas — rapido dado el tamano del dataset de entrenamiento.</td>
#     </tr>
#   </table>
# </div>

# %%
print("=" * 60)
print("VERIFICACION DEL ENTORNO")
print("=" * 60)

for schema in [SCHEMA_BRONZE, SCHEMA_SILVER, SCHEMA_GOLD]:
    tablas = spark.sql(f"SHOW TABLES IN {CATALOG_NAME}.{schema}").collect()
    print(f"\n{schema.upper()} — {len(tablas)} tabla(s):")
    for t in tablas:
        cnt = spark.table(f"{CATALOG_NAME}.{schema}.{t.tableName}").count()
        det = spark.sql(f"DESCRIBE DETAIL {CATALOG_NAME}.{schema}.{t.tableName}").first()
        print(f"  {t.tableName:<20} {cnt:>10,} registros  |  formato: {det['format']}  |  {det['numFiles']} archivos")

print("\n" + "=" * 60)
print("VISTAZO DE NEGOCIO")
print("=" * 60)

total_eventos = spark.table(tbl(SCHEMA_BRONZE, "eventos_carrito")).count()
total_compras = spark.table(tbl(SCHEMA_BRONZE, "eventos_carrito")).filter("tipo_evento = 'purchase'").count()
total_agregar = spark.table(tbl(SCHEMA_BRONZE, "eventos_carrito")).filter("tipo_evento = 'add_to_cart'").count()
print(f"Tasa add_to_cart -> purchase (aprox, a nivel evento): {total_compras / total_agregar * 100:.1f}%")

total_trx  = spark.table(tbl(SCHEMA_BRONZE, "transacciones")).count()
total_fraude = spark.table(tbl(SCHEMA_BRONZE, "transacciones")).filter("es_fraude = true").count()
print(f"Tasa de fraude sintetica en transacciones: {total_fraude / total_trx * 100:.2f}% ({total_fraude:,} de {total_trx:,})")

print("\nTodos los objetos listos. Puede continuar con el Modulo 1 — Sesion 1.")

# %% [markdown]
# <div style="box-sizing:border-box;width:100%;background:linear-gradient(90deg,#0a2a6e,#0d9488);height:3px;border-radius:2px;margin:20px 0 8px 0;"></div>
# <div style="box-sizing:border-box;width:100%;display:flex;justify-content:space-between;color:#64748b;font-size:12px;">
#   <span>Setup &middot; Notebook 01 &nbsp;&middot;&nbsp; Siguiente: <strong>Modulo 1 &middot; Sesion 1</strong></span>
# </div>
